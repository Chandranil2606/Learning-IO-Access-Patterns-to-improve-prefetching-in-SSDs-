# %%
# Author: Chandranil Chakraborttii
# Project: Learning I/O Access Patterns to Improve Prefetching in SSDs
# Paper Link :https://www.researchgate.net/profile/Chandranil_Chakraborttii/publication/344379801_Learning_IO_Access_Patterns_to_Improve_Prefetching_in_SSDs/links/5f6e28fba6fdcc00863adb13/Learning-I-O-Access-Patterns-to-Improve-Prefetching-in-SSDs.pdf
# Loading libraries

import csv
import sys
import pandas as pd
import os
import glob
from collections import Counter

# Loading all files
# Check coverage
# Update in output file

path  = r"/soe/hlitz/maxwell/notebooks/Prefetching_SSD/Data/output/MSR-Cambridge/Part1/"  
output  = r"/soe/hlitz/maxwell/notebooks/Prefetching_SSD/Data/output/MSR-Cambridge/" 
names = ['TimeStamp','Host_Name','DiskNumber','Operation_Type','ByteOffset','IOSize','Response_Time','DiskNum']
cols_to_drop = ['TimeStamp','Host_Name','DiskNumber','Operation_Type','IOSize','Response_Time','DiskNum']


prxy_cols = ['TimeStamp','Host_Name','DiskNumber','Operation_Type','ByteOffset','IOSize','Response_Time','DiskNum']
cols_to_drop_prxy = ['TimeStamp','Host_Name','DiskNumber','Operation_Type','IOSize','Response_Time','DiskNum']

all_files = glob.glob(os.path.join(path, "*.csv"))
print(len(all_files))


Filename = []
Num_obs = []
Coverage_Offset_1000 = []
Coverage_Delta_1000 = []
Coverage_Delta2_1000 = []

count = 0
for file in all_files:
    count=count+1
    spl  = file.split("/")
    p = len(spl)
    name = spl[p-1]
    part_num = spl[p-2]
    print("Processing File Number :" + str(count))
    print("File Name :"  + str(name))

    Filename.append(name)
  
    df = pd.read_csv(file,skiprows=2,engine='python',index_col=False)
    if "part" in file:
        df.columns = prxy_cols
        df = df.drop(cols_to_drop_prxy, axis=1)
    else:
        df.columns = names
        df = df.drop(cols_to_drop, axis=1)
        
        
    df['ByteOffset_Delta'] = df['ByteOffset'] - df['ByteOffset'].shift(-1)
    
    Num_obs.append(len(df))
    print("Total Number of Observations")
    print(len(df))
    
    x = Counter(df['ByteOffset'])
    vals = {}
    vals =  x.most_common(1000)
    bo_list = []
    coverage = 0
    for key,value in vals:
        bo_list.append(key)
        coverage = coverage + value
    print("Percentage Coverage : Offset" + str((coverage/len(df))*100))
#     print((coverage/len(df))*100)
    Coverage_Offset_1000.append((coverage/len(df))*100)
    if ((coverage/len(df))*100  > 95.0):
        print("FLAGGED....!")
        print("FLAGGED....!")
        print("FLAGGED....!")
    
    
    

    x = Counter(df['ByteOffset_Delta'])
    vals = {}
    vals =  x.most_common(1000)
    bo_list = []
    coverage = 0
    for key,value in vals:
        bo_list.append(key)
        coverage = coverage + value
    

#     print("Percentage Coverage : Delta")
#     print((coverage/len(df))*100)
    print("Percentage Coverage : Delta" + str((coverage/len(df))*100))
    Coverage_Delta_1000.append((coverage/len(df))*100)
    if ((coverage/len(df))*100  > 95.0):
        print("FLAGGED....!")
        print("FLAGGED....!")
        print("FLAGGED....!")
    
    
    df['ByteOffset_Delta'] = df['ByteOffset_Delta'].fillna(0)
    df['ByteOffset_Delta_2'] = df['ByteOffset_Delta'] - df['ByteOffset_Delta'].shift(-1)
    
    x = Counter(df['ByteOffset_Delta_2'])
    vals = {}
    vals =  x.most_common(1000)
    bo_list = []
    coverage_1 = 0
    for key,value in vals:
        bo_list.append(key)
        coverage_1 = coverage_1 + value
    

#     print("Percentage Coverage : Delta 2")
#     print((coverage/len(df))*100)
    print("Percentage Coverage : Delta 2   " + str((coverage_1/len(df))*100))
    Coverage_Delta2_1000.append((coverage_1/len(df))*100)
    if ((coverage/len(df))*100  > 95.0):
        print("FLAGGED....!")
        print("FLAGGED....!")
        print("FLAGGED....!")
    
    
    print()
    print()
    print()

result_col = ['Filename','Num_obs','Coverage_Offset_1000','Coverage_Delta_1000']
result = pd.DataFrame(columns=result_col)
result['Filename'] = Filename
result['Num_obs'] = Num_obs
result['Coverage_Offset_1000'] = Coverage_Offset_1000
result['Coverage_Delta_1000'] = Coverage_Delta_1000
result['Coverage_Delta2_1000'] = Coverage_Delta2_1000

outname = part_num +'.csv'
filename_wr_out = os.path.join(output,outname)

result.to_csv(filename_wr_out,index=False)
# Out:
# 22
# Processing File Number :1
# File Name :proj_3.csv
# Total Number of Observations
# 2244642
# Percentage Coverage : Offset2.769573054411349
# Percentage Coverage : Delta91.65929355327042
# Percentage Coverage : Delta 2   88.55372037055352
#
#
#
# Processing File Number :2
# File Name :prxy1_part7.csv
# Total Number of Observations
# 16869203
# Percentage Coverage : Offset36.844408120525905
# Percentage Coverage : Delta58.52577623258194
# Percentage Coverage : Delta 2   35.203394019266945
#
#
#
# Processing File Number :3
# File Name :mds_0.csv
# Total Number of Observations
# 1211032
# Percentage Coverage : Offset76.93942026304838
# Percentage Coverage : Delta63.46248488892119
# Percentage Coverage : Delta 2   44.61129020537855
#
#
#
# Processing File Number :4
# File Name :prxy1_part4.csv
# Total Number of Observations
# 16859429
# Percentage Coverage : Offset35.98431477127725
# Percentage Coverage : Delta57.11102078249507
# Percentage Coverage : Delta 2   34.28004590191044
#
#
#
# Processing File Number :5
# File Name :mds_1.csv
# Total Number of Observations
# 1637709
# Percentage Coverage : Offset2.8102062087953352
# Percentage Coverage : Delta92.96138691305966
# Percentage Coverage : Delta 2   89.53935039741494
#
#
#
# Processing File Number :6
# File Name :prxy1_part1.csv
# Total Number of Observations
# 16871124
# Percentage Coverage : Offset32.710565105205795
# Percentage Coverage : Delta55.944020090184864
# Percentage Coverage : Delta 2   33.726484376500345
#
#
#
# Processing File Number :7
# File Name :prn_1.csv
# Total Number of Observations
# 11233409
# Percentage Coverage : Offset5.704911127156502
# Percentage Coverage : Delta41.07530492302025
# Percentage Coverage : Delta 2   28.394470458611448
#
#
#
# Processing File Number :8
# File Name :prxy_0.csv
# Total Number of Observations
# 12518966
# Percentage Coverage : Offset58.53122374483644
# Percentage Coverage : Delta84.49323210878597
# Percentage Coverage : Delta 2   76.4066617003353
#
#
#
# Processing File Number :9
# File Name :hm_1.csv
# Total Number of Observations
# 609309
# Percentage Coverage : Offset95.35867679617402
# FLAGGED....!
# FLAGGED....!
# FLAGGED....!
# Percentage Coverage : Delta40.248872082966116
# Percentage Coverage : Delta 2   17.803282078551277
#
#
#
# Processing File Number :10
# File Name :prxy1_part6.csv
# Total Number of Observations
# 16864398
# Percentage Coverage : Offset37.00618308462597
# Percentage Coverage : Delta58.29766351576854
# Percentage Coverage : Delta 2   35.1126378777351
#
#
#
# Processing File Number :11
# File Name :prxy1_part2.csv
# Total Number of Observations
# 16865525
# Percentage Coverage : Offset33.85322425480381
# Percentage Coverage : Delta56.36668292270771
# Percentage Coverage : Delta 2   33.86213592520838
#
#
#
# Processing File Number :12
# File Name :proj_2.csv
# Total Number of Observations
# 29266480
# Percentage Coverage : Offset0.4320369241535026
# Percentage Coverage : Delta83.24354004991376
# Percentage Coverage : Delta 2   76.30386708616821
#
#
#
# Processing File Number :13
# File Name :prxy1_part10.csv
# Total Number of Observations
# 16864520
# Percentage Coverage : Offset33.512237525882746
# Percentage Coverage : Delta55.98159923911265
# Percentage Coverage : Delta 2   33.43314840861169
#
#
#
# Processing File Number :14
# File Name :prn_0.csv
# Total Number of Observations
# 5585884
# Percentage Coverage : Offset35.07903135833111
# Percentage Coverage : Delta68.93011025649656
# Percentage Coverage : Delta 2   52.70258028988787
#
#
#
# Processing File Number :15
# File Name :prxy1_part5.csv
# Total Number of Observations
# 16860630
# Percentage Coverage : Offset36.56365746712905
# Percentage Coverage : Delta57.5132601806694
# Percentage Coverage : Delta 2   34.492910407262364
#
#
#
# Processing File Number :16
# File Name :proj_4.csv
# Total Number of Observations
# 6465637
# Percentage Coverage : Offset0.7170523182789259
# Percentage Coverage : Delta88.39651839408863
# Percentage Coverage : Delta 2   82.9410002448328
#
#
#
# Processing File Number :17
# File Name :prxy1_part9.csv
# Total Number of Observations
# 16863265
# Percentage Coverage : Offset32.78920778390187
# Percentage Coverage : Delta55.43297220318841
# Percentage Coverage : Delta 2   33.02719253952304
#
#
#
# Processing File Number :18
# File Name :prxy1_part3.csv
# Total Number of Observations
# 16859792
# Percentage Coverage : Offset35.19823376231451
# Percentage Coverage : Delta56.57078687566253
# Percentage Coverage : Delta 2   33.91356192294662
#
#
#
# Processing File Number :19
# File Name :prxy1_part8.csv
# Total Number of Observations
# 16861058
# Percentage Coverage : Offset32.151980024029335
# Percentage Coverage : Delta54.92979740654471
# Percentage Coverage : Delta 2   32.77152003154251
#
#
#
# Processing File Number :20
# File Name :proj_1.csv
# Total Number of Observations
# 23639740
# Percentage Coverage : Offset1.842228383222489
# Percentage Coverage : Delta76.02060344149301
# Percentage Coverage : Delta 2   66.5110952996945
#
#
#
# Processing File Number :21
# File Name :proj_0.csv
# Total Number of Observations
# 4224522
# Percentage Coverage : Offset34.27753483115959
# Percentage Coverage : Delta65.36550170646525
# Percentage Coverage : Delta 2   51.6132476052912
#
#
#
# Processing File Number :22
# File Name :hm_0.csv
# Total Number of Observations
# 3993314
# Percentage Coverage : Offset50.52532808589557
# Percentage Coverage : Delta52.41633891048888
# Percentage Coverage : Delta 2   33.90356981694903

# %%
import csv
import sys
import pandas as pd
import os
import glob
from collections import Counter



path  = r"/soe/hlitz/maxwell/notebooks/Prefetching_SSD/Data/output/MSR-Cambridge/Part2/"  
output  = r"/soe/hlitz/maxwell/notebooks/Prefetching_SSD/Data/output/MSR-Cambridge/" 
names = ['TimeStamp','Host_Name','DiskNumber','Operation_Type','ByteOffset','IOSize','Response_Time','DiskNum']
cols_to_drop = ['TimeStamp','Host_Name','DiskNumber','Operation_Type','IOSize','Response_Time','DiskNum']


prxy_cols = ['TimeStamp','Host_Name','DiskNumber','Operation_Type','ByteOffset','IOSize','Response_Time','DiskNum']
cols_to_drop_prxy = ['TimeStamp','Host_Name','DiskNumber','Operation_Type','IOSize','Response_Time','DiskNum']

all_files = glob.glob(os.path.join(path, "*.csv"))
print(len(all_files))


Filename = []
Num_obs = []
Coverage_Offset_1000 = []
Coverage_Delta_1000 = []
Coverage_Delta2_1000 = []

count = 0
for file in all_files:
    count=count+1
    spl  = file.split("/")
    p = len(spl)
    name = spl[p-1]
    part_num = spl[p-2]
    print("Processing File Number :" + str(count))
    print("File Name :"  + str(name))

    Filename.append(name)
  
    df = pd.read_csv(file,engine='python',index_col=False)
    if "part" in file:
        df.columns = prxy_cols
        df = df.drop(cols_to_drop_prxy, axis=1)
    else:
        df.columns = names
        df = df.drop(cols_to_drop, axis=1)
        
        
    df['ByteOffset_Delta'] = df['ByteOffset'] - df['ByteOffset'].shift(-1)
    
    Num_obs.append(len(df))
    print("Total Number of Observations")
    print(len(df))
    
    x = Counter(df['ByteOffset'])
    vals = {}
    vals =  x.most_common(1000)
    bo_list = []
    coverage = 0
    for key,value in vals:
        bo_list.append(key)
        coverage = coverage + value
    print("Percentage Coverage : Offset" + str((coverage/len(df))*100))
#     print((coverage/len(df))*100)
    Coverage_Offset_1000.append((coverage/len(df))*100)
    if ((coverage/len(df))*100  > 95.0):
        print("FLAGGED....!")
        print("FLAGGED....!")
        print("FLAGGED....!")
    
    
    

    x = Counter(df['ByteOffset_Delta'])
    vals = {}
    vals =  x.most_common(1000)
    bo_list = []
    coverage = 0
    for key,value in vals:
        bo_list.append(key)
        coverage = coverage + value
    

#     print("Percentage Coverage : Delta")
#     print((coverage/len(df))*100)
    print("Percentage Coverage : Delta" + str((coverage/len(df))*100))
    Coverage_Delta_1000.append((coverage/len(df))*100)
    if ((coverage/len(df))*100  > 95.0):
        print("FLAGGED....!")
        print("FLAGGED....!")
        print("FLAGGED....!")
    
    
    df['ByteOffset_Delta'] = df['ByteOffset_Delta'].fillna(0)
    df['ByteOffset_Delta_2'] = df['ByteOffset_Delta'] - df['ByteOffset_Delta'].shift(-1)
    
    x = Counter(df['ByteOffset_Delta_2'])
    vals = {}
    vals =  x.most_common(1000)
    bo_list = []
    coverage_1 = 0
    for key,value in vals:
        bo_list.append(key)
        coverage_1 = coverage_1 + value
    

#     print("Percentage Coverage : Delta 2")
#     print((coverage/len(df))*100)
    print("Percentage Coverage : Delta 2   " + str((coverage_1/len(df))*100))
    Coverage_Delta2_1000.append((coverage_1/len(df))*100)
    if ((coverage/len(df))*100  > 95.0):
        print("FLAGGED....!")
        print("FLAGGED....!")
        print("FLAGGED....!")
    
    
    print()
    print()
    print()

result_col = ['Filename','Num_obs','Coverage_Offset_1000','Coverage_Delta_1000']
result = pd.DataFrame(columns=result_col)
result['Filename'] = Filename
result['Num_obs'] = Num_obs
result['Coverage_Offset_1000'] = Coverage_Offset_1000
result['Coverage_Delta_1000'] = Coverage_Delta_1000
result['Coverage_Delta2_1000'] = Coverage_Delta2_1000

outname = part_num +'.csv'
filename_wr_out = os.path.join(output,outname)

result.to_csv(filename_wr_out,index=False)
# Out:
# 23
# Processing File Number :1
# File Name :wdev_0.csv
# Total Number of Observations
# 1143261
# Percentage Coverage : Offset70.17881306193424
# Percentage Coverage : Delta58.48113422919175
# Percentage Coverage : Delta 2   38.607894435303926
#
#
#
# Processing File Number :2
# File Name :src1_0.csv
# Total Number of Observations
# 37415613
# Percentage Coverage : Offset0.41992095652689154
# Percentage Coverage : Delta75.03243098008309
# Percentage Coverage : Delta 2   65.5098207264438
#
#
#
# Processing File Number :3
# File Name :wdev_3.csv
# Total Number of Observations
# 682
# Percentage Coverage : Offset100.0
# FLAGGED....!
# FLAGGED....!
# FLAGGED....!
# Percentage Coverage : Delta100.0
# FLAGGED....!
# FLAGGED....!
# FLAGGED....!
# Percentage Coverage : Delta 2   100.0
# FLAGGED....!
# FLAGGED....!
# FLAGGED....!
#
#
#
# Processing File Number :4
# File Name :src2_2.csv
# Total Number of Observations
# 1156885
# Percentage Coverage : Offset2.826815111268622
# Percentage Coverage : Delta83.39688041594454
# Percentage Coverage : Delta 2   77.37147598940257
#
#
#
# Processing File Number :5
# File Name :rsrch_2.csv
# Total Number of Observations
# 207587
# Percentage Coverage : Offset23.072254042883227
# Percentage Coverage : Delta55.18939047242842
# Percentage Coverage : Delta 2   36.09137373727641
#
#
#
# Processing File Number :6
# File Name :src1_2.csv
# Total Number of Observations
# 1907773
# Percentage Coverage : Offset38.79098823602179
# Percentage Coverage : Delta56.25732201891944
# Percentage Coverage : Delta 2   41.426521918488206
#
#
#
# Processing File Number :7
# File Name :rsrch_0.csv
# Total Number of Observations
# 1433655
# Percentage Coverage : Offset74.76736034820092
# Percentage Coverage : Delta57.10355699244239
# Percentage Coverage : Delta 2   35.88345871217273
#
#
#
# Processing File Number :8
# File Name :src1_1.csv
# Total Number of Observations
# 45746222
# Percentage Coverage : Offset0.7770543324867352
# Percentage Coverage : Delta28.965961385838597
# Percentage Coverage : Delta 2   16.01438912266897
#
#
#
# Processing File Number :9
# File Name :web_2.csv
# Total Number of Observations
# 5175368
# Percentage Coverage : Offset0.5528495751413233
# Percentage Coverage : Delta96.8096181759442
# FLAGGED....!
# FLAGGED....!
# FLAGGED....!
# Percentage Coverage : Delta 2   95.17947322779752
# FLAGGED....!
# FLAGGED....!
# FLAGGED....!
#
#
#
# Processing File Number :10
# File Name :web_0.csv
# Total Number of Observations
# 2029945
# Percentage Coverage : Offset55.43800447795384
# Percentage Coverage : Delta57.82984268046671
# Percentage Coverage : Delta 2   39.180470406833685
#
#
#
# Processing File Number :11
# File Name :usr_2.csv
# Total Number of Observations
# 10570046
# Percentage Coverage : Offset9.934554684057193
# Percentage Coverage : Delta79.07300498029998
# Percentage Coverage : Delta 2   72.24290225416237
#
#
#
# Processing File Number :12
# File Name :src2_1.csv
# Total Number of Observations
# 657774
# Percentage Coverage : Offset2.016346039825229
# Percentage Coverage : Delta93.99489794367062
# Percentage Coverage : Delta 2   91.79094947504765
#
#
#
# Processing File Number :13
# File Name :web_1.csv
# Total Number of Observations
# 160891
# Percentage Coverage : Offset40.92273651105407
# Percentage Coverage : Delta77.7961477024818
# Percentage Coverage : Delta 2   66.76321236116377
#
#
#
# Processing File Number :14
# File Name :rsrch_1.csv
# Total Number of Observations
# 13780
# Percentage Coverage : Offset74.644412191582
# Percentage Coverage : Delta59.99274310595065
# Percentage Coverage : Delta 2   39.76052249637155
#
#
#
# Processing File Number :15
# File Name :wdev_1.csv
# Total Number of Observations
# 1055
# Percentage Coverage : Offset100.0
# FLAGGED....!
# FLAGGED....!
# FLAGGED....!
# Percentage Coverage : Delta100.0
# FLAGGED....!
# FLAGGED....!
# FLAGGED....!
# Percentage Coverage : Delta 2   100.0
# FLAGGED....!
# FLAGGED....!
# FLAGGED....!
#
#
#
# Processing File Number :16
# File Name :stg_1.csv
# Total Number of Observations
# 2196861
# Percentage Coverage : Offset22.955207452815632
# Percentage Coverage : Delta75.26479827353666
# Percentage Coverage : Delta 2   67.82595712700986
#
#
#
# Processing File Number :17
# File Name :usr_1.csv
# Total Number of Observations
# 45283980
# Percentage Coverage : Offset2.649820090901904
# Percentage Coverage : Delta82.12218758156858
# Percentage Coverage : Delta 2   76.18443211042846
#
#
#
# Processing File Number :18
# File Name :web_3.csv
# Total Number of Observations
# 31380
# Percentage Coverage : Offset11.02931803696622
# Percentage Coverage : Delta78.4384958572339
# Percentage Coverage : Delta 2   71.68897386870619
#
#
#
# Processing File Number :19
# File Name :stg_0.csv
# Total Number of Observations
# 2030915
# Percentage Coverage : Offset65.47398586351471
# Percentage Coverage : Delta51.13104191952888
# Percentage Coverage : Delta 2   31.96116036367844
#
#
#
# Processing File Number :20
# File Name :usr_0.csv
# Total Number of Observations
# 2237889
# Percentage Coverage : Offset59.90851199500958
# Percentage Coverage : Delta63.79677454958669
# Percentage Coverage : Delta 2   47.89527094507368
#
#
#
# Processing File Number :21
# File Name :ts_0.csv
# Total Number of Observations
# 1801734
# Percentage Coverage : Offset67.71854224874481
# Percentage Coverage : Delta55.70572570645833
# Percentage Coverage : Delta 2   36.40376437365338
#
#
#
# Processing File Number :22
# File Name :wdev_2.csv
# Total Number of Observations
# 181266
# Percentage Coverage : Offset47.5902816854788
# Percentage Coverage : Delta59.16994913552459
# Percentage Coverage : Delta 2   38.79050676905763
#
#
#
# Processing File Number :23
# File Name :src2_0.csv
# Total Number of Observations
# 1557814
# Percentage Coverage : Offset74.6164176211024
# Percentage Coverage : Delta53.47249414885218
# Percentage Coverage : Delta 2   30.828070616902913

# %%
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a29405eb924b> in <module>
# ----> 1 df.head(5)
#
# NameError: name 'df' is not defined
